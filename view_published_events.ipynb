# %%
import paho.mqtt.client as mqtt
import json

def on_connect(client, userdata, connect_flags, reason_code, properties):
  print("Connected with result code " + str(reason_code))
  client.subscribe("comp5339/t01_group8", qos =1)

def on_subscribe(client, userdata, mid, reason_codes, properties):
  print(f"Subscribed successfully!")

counter = 0
def on_message(client, userdata, msg):
  data = json.loads(msg.payload)
  global counter
  counter +=1
  print(f"[event {counter}] {data}")

client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message
client.on_subscribe = on_subscribe

client.connect("test.mosquitto.org", 1883, 60)
# Out:
# <MQTTErrorCode.MQTT_ERR_SUCCESS: 0>

# %%
client.loop_forever()
# Out:
# Connected with result code Success
# Subscribed successfully!
# [event 1] {'facility_id': 'CANUNDA1', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 695.8125, 'co2_tonnes': 0.0}
# [event 2] {'facility_id': 'CAPBES', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 33.21, 'co2_tonnes': 0.0}
# [event 3] {'facility_id': 'CAPTL_WF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 86.4974, 'co2_tonnes': 0.0}
# [event 4] {'facility_id': 'CATHROCK', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 430.5, 'co2_tonnes': 0.0}
# [event 5] {'facility_id': 'CBWWBA', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.039, 'co2_tonnes': 0.0}
# [event 6] {'facility_id': 'CETHANA', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 1757.6208, 'co2_tonnes': 0.0}
# [event 7] {'facility_id': 'CHALLWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 212.5, 'co2_tonnes': 0.0}
# [event 8] {'facility_id': 'CHBESS', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 773.4841, 'co2_tonnes': 0.0}
# [event 9] {'facility_id': 'CHILDSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 10] {'facility_id': 'CHYTWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 204.36, 'co2_tonnes': 0.0}
# [event 11] {'facility_id': 'CLARESF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 12] {'facility_id': 'CLEMGPWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 142.6293, 'co2_tonnes': 0.0}
# [event 13] {'facility_id': 'CLERMSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 14] {'facility_id': 'CLOVER', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 15] {'facility_id': 'CLRKCWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 1543.8896, 'co2_tonnes': 0.0}
# [event 16] {'facility_id': 'CLUNY', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 117.0696, 'co2_tonnes': 0.0}
# [event 17] {'facility_id': 'COHUNSF1', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 18] {'facility_id': 'COLEASF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 19] {'facility_id': 'COLONGRA', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 20] {'facility_id': 'COLUMSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 21] {'facility_id': 'COLWF01', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 813.7668000000001, 'co2_tonnes': 0.0}
# [event 22] {'facility_id': 'CONDONG1', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 346.28999999999996, 'co2_tonnes': 1.05}
# [event 23] {'facility_id': 'COOPGWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 119.8, 'co2_tonnes': 0.0}
# [event 24] {'facility_id': 'CPSA', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 25] {'facility_id': 'CROOKWF2', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 900.6174000000001, 'co2_tonnes': 0.0}
# [event 26] {'facility_id': 'CROOKWF3', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 490.4993, 'co2_tonnes': 0.0}
# [event 27] {'facility_id': 'CROWLWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 92.5456, 'co2_tonnes': 0.0}
# [event 28] {'facility_id': 'CRURWF1', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 1405.494, 'co2_tonnes': 0.0}
# [event 29] {'facility_id': 'CRWASF1', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 30] {'facility_id': 'CSPVPS', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 31] {'facility_id': 'CTHLWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 32] {'facility_id': 'CULCSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 33] {'facility_id': 'CULLERIN', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 106.81, 'co2_tonnes': 0.0}
# [event 34] {'facility_id': 'DALNTH', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 3.2186, 'co2_tonnes': 0.0}
# [event 35] {'facility_id': 'DARLSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 36] {'facility_id': 'DARTM', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 37] {'facility_id': 'DAYDSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 38] {'facility_id': 'DDPS1', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 902.1768, 'co2_tonnes': 60.8832}
# [event 39] {'facility_id': 'DDSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 40] {'facility_id': 'DEIBDL', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 41] {'facility_id': 'DEVILS_G', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 1985.6064, 'co2_tonnes': 0.0}
# [event 42] {'facility_id': 'DIAPURWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 226.3, 'co2_tonnes': 0.0}
# [event 43] {'facility_id': 'DPNTB', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': -24.6544, 'co2_tonnes': 0.0}
# [event 44] {'facility_id': 'DRYCGT', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 45] {'facility_id': 'DULAWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 10.8, 'co2_tonnes': 0.0}
# [event 46] {'facility_id': 'DUNDWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 980.04, 'co2_tonnes': 0.0}
# [event 47] {'facility_id': 'EDENVSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 48] {'facility_id': 'EILDON', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 49] {'facility_id': 'ELAINEWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 134.8, 'co2_tonnes': 0.0}
# [event 50] {'facility_id': 'EMERASF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 51] {'facility_id': 'ERARING', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 34382.6399, 'co2_tonnes': 2554.625}
# [event 52] {'facility_id': 'ERB', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': -0.6226, 'co2_tonnes': 0.0}
# [event 53] {'facility_id': 'ERGT01', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 54] {'facility_id': 'FINLEYSF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 0.0, 'co2_tonnes': 0.0}
# [event 55] {'facility_id': 'FISHER', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 444.1, 'co2_tonnes': 0.0}
# [event 56] {'facility_id': 'FLYCRKWF', 'timestamp': '2025-10-29T00:05:00+10:00', 'power_mw': 720.0, 'co2_tonnes': 0.0}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client.loop_forever()
#
# File ~/miniconda3/envs/comp5339/lib/python3.10/site-packages/paho/mqtt/client.py:2297, in Client.loop_forever(self, timeout, retry_first_connection)
#    2295 rc = MQTTErrorCode.MQTT_ERR_SUCCESS
#    2296 while rc == MQTTErrorCode.MQTT_ERR_SUCCESS:
# -> 2297     rc = self._loop(timeout)
#    2298     # We don't need to worry about locking here, because we've
#    2299     # either called loop_forever() when in single threaded mode, or
#    2300     # in multi threaded mode when loop_stop() has been called and
#    2301     # so no other threads can access _out_packet or _messages.
#    2302     if (self._thread_terminate is True
#    2303         and len(self._out_packet) == 0
#    2304             and len(self._out_messages) == 0):
#
# File ~/miniconda3/envs/comp5339/lib/python3.10/site-packages/paho/mqtt/client.py:1663, in Client._loop(self, timeout)
#    1660     rlist = [self._sock, self._sockpairR]
#    1662 try:
# -> 1663     socklist = select.select(rlist, wlist, [], timeout)
#    1664 except TypeError:
#    1665     # Socket isn't correct type, in likelihood connection is lost
#    1666     # ... or we called disconnect(). In that case the socket will
#    (...)
#    1669     # rc != MQTT_ERR_SUCCESS and we don't want state to change from
#    1670     # mqtt_cs_disconnecting.
#    1671     if self._state not in (_ConnectionState.MQTT_CS_DISCONNECTING, _ConnectionState.MQTT_CS_DISCONNECTED):
#
# KeyboardInterrupt:
